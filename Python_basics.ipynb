# %%
str1 = input(print ('Write here your first name '))
str2 = input(print ('Write here your last name'))
print ( str2 , str1 )

# %%
n = int (input('Enter a number: '))
strg1 = str(n)
strg2 = strg1 + strg1 
strg3 = strg1 + strg1 + strg1 
strg4 = int(strg1) + int(strg2) + int(strg3)
print (strg4)

# %%
n = int (input('Enter a number here: '))
if n % 2: 
  print ('The numer you have entered is odd.')
else:
  print('The number you have entered is even.')

# %%
for x in range (2000, 3201):
  if x % 7 == 0 and x % 5 != 0:
    print (x, end= ',')

# %%
x = int(input('Enter a number here: '))
y = 1
for i in range(1, x + 1):
  y = y * i
  print(y)
if x == 0:
  print('1')
if x < 0:
  print('ERROR')

# %%
x = input('Enter a Word: ')
for i in range (len(x)):
  if i % 2 == 0:
    print(x[i], end= '')

# %%
price = int(input('Enter the price of the product: '))
if price == 500 or price > 500:
  x = price - (price / 2)
  print(x)
elif price in range (200, 500):
  x =price - (price * 0.3)
  print(x)
else:
  x = price - (price * 0.1)
  print(x)
